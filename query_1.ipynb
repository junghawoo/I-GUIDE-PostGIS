# %% [markdown]
# ### Problem
#
# What vulnerable entities fall within an individual dams inundation zone (output in a list, showing the different entities for a selected dam)
# Count how many vulnerable entities are within a dam's inundation zone (just a number)

# %%
import psycopg2
from tabulate import tabulate

# %%
db_params = {
    "dbname": "gisdb",
    "user": "admin",
    "password": "admin",
    "host": "localhost",
    "port": 5432,
}

try:
    conn = psycopg2.connect(**db_params)
    print("Connected to the database successfully.")
except Exception as e:
    print(f"Error connecting to the database: {e}")
# Out:
# Connected to the database successfully.

# %%
def get_actual_column_names(conn, table, schema="public"):
    """Return the case-sensitive column names for schema.table"""
    with conn.cursor() as cur:
        cur.execute(
            """
            SELECT column_name
            FROM information_schema.columns
            WHERE table_schema = %s AND table_name = %s
            """,
            (schema, table),
        )
        return [r[0] for r in cur.fetchall()]

# %%
def list_available_dams(conn, limit=50):
    """Return dams sorted by inundation-polygon area (largest first)."""
    with conn.cursor() as cur:
        dam_cols = get_actual_column_names(conn, "utah_dams")
        name_col = next(c for c in dam_cols if c.upper() == "NAME")
        type_col = next(c for c in dam_cols if c.upper() == "TYPE")
        geom_col = "geom"

        cur.execute(
            f"""
            SELECT "{name_col}", "{type_col}",
                   ST_Area("{geom_col}"::geography) / 1e6 AS area_sq_km
            FROM utah_dams
            ORDER BY area_sq_km DESC
            LIMIT %s
            """,
            (limit,),
        )
        rows = cur.fetchall()

    headers = ["Dam Name", "Type", "Inundation Area (sq km)"]
    print("\nTop", limit, "Utah dams by inundation area:")
    print(tabulate([[r[0], r[1], round(r[2], 2)] for r in rows], headers, tablefmt="grid"))
    return rows  # [(name, type, area)]

# %%
def analyze_power_plants_at_risk(conn, dam_name):
    """Print and return the power plants whose points fall within *dam_name* polygon."""
    with conn.cursor() as cur:
        # Column discovery – dams
        dam_cols = get_actual_column_names(conn, "utah_dams")
        name_col_dam = next(c for c in dam_cols if c.upper() == "NAME")
        geom_col_dam = "geom"

        # Column discovery – power plants
        pp_cols = get_actual_column_names(conn, "power_plants")
        name_col_pp = next(c for c in pp_cols if c.upper() == "NAME")
        type_col_pp = next(c for c in pp_cols if c.upper() == "TYPE")
        fuel_col = next(c for c in pp_cols if c.upper() == "PRIM_FUEL")
        cap_col = next(c for c in pp_cols if c.upper() == "SUMMER_CAP")
        geom_col_pp = "geom"

        # Spatial query – intersects rather than contains (safer for points)
        cur.execute(
            f"""
            SELECT p."{name_col_pp}", p."{type_col_pp}", p."{fuel_col}", p."{cap_col}"
            FROM   utah_dams d
            JOIN   power_plants p
              ON   ST_Intersects(d."{geom_col_dam}", p."{geom_col_pp}")
            WHERE  d."{name_col_dam}" = %s
            ORDER  BY p."{cap_col}" DESC NULLS LAST
            """,
            (dam_name,),
        )
        rows = cur.fetchall()

    print("\n--- Power Plants at Risk ---")
    if rows:
        headers = ["Plant Name", "Type", "Primary Fuel", "Capacity (MW)"]
        print(tabulate(rows, headers, tablefmt="grid"))
    else:
        print(f"No power plants found within the inundation zone of '{dam_name}'.")
    return rows

# %%
dams = list_available_dams(conn)
print("\nEnter a dam name to analyze or type 'ALL' for every dam")
# Out:
# Top 50 Utah dams by inundation area:
# +--------------------------------------+-----------+---------------------------+
# | Dam Name                             | Type      |   Inundation Area (sq km) |
# +======================================+===========+===========================+
# | SEVIER BRIDGE                        | PMF       |                    863.32 |
# +--------------------------------------+-----------+---------------------------+
# | SEVIER BRIDGE                        | Sunny     |                    808.46 |
# +--------------------------------------+-----------+---------------------------+
# | DMAD                                 | PMF       |                    581.88 |
# +--------------------------------------+-----------+---------------------------+
# | PIUTE                                | PMF       |                    224.4  |
# +--------------------------------------+-----------+---------------------------+
# | SETTLEMENT CANYON                    | PMF       |                    154.61 |
# +--------------------------------------+-----------+---------------------------+
# | NEWCASTLE                            | PMF       |                    151.42 |
# +--------------------------------------+-----------+---------------------------+
# | ENTERPRISE (UPPER)                   | PMF       |                    150.55 |
# +--------------------------------------+-----------+---------------------------+
# | ENTERPRISE (LOWER)                   | PMF       |                    150.15 |
# +--------------------------------------+-----------+---------------------------+
# | Big Sand Wash                        | PMF       |                    130.02 |
# +--------------------------------------+-----------+---------------------------+
# | NEWCASTLE                            | Sunny     |                    114.46 |
# +--------------------------------------+-----------+---------------------------+
# | CLIFF LAKE (DUCHESNE)                | PMF       |                    100.54 |
# +--------------------------------------+-----------+---------------------------+
# | SETTLEMENT CANYON                    | Sunny     |                     93.49 |
# +--------------------------------------+-----------+---------------------------+
# | WHITEROCKS LAKE                      | PMF       |                     93.34 |
# +--------------------------------------+-----------+---------------------------+
# | CLIFF LAKE (DUCHESNE)                | Sunny     |                     84.26 |
# +--------------------------------------+-----------+---------------------------+
# | DMAD                                 | Sunny     |                     81.18 |
# +--------------------------------------+-----------+---------------------------+
# | WHITEROCKS LAKE                      | Sunny     |                     77.99 |
# +--------------------------------------+-----------+---------------------------+
# | ROCKY FORD (BEAVER)                  | PMF       |                     71.68 |
# +--------------------------------------+-----------+---------------------------+
# | PORCUPINE                            | PMF       |                     66.55 |
# +--------------------------------------+-----------+---------------------------+
# | UTAH POWER & LIGHT - CUTLER          | PMF       |                     45.99 |
# +--------------------------------------+-----------+---------------------------+
# | ROCKY FORD (BEAVER)                  | Sunny     |                     42.08 |
# +--------------------------------------+-----------+---------------------------+
# | CHEPETA                              | Estimated |                     40.29 |
# +--------------------------------------+-----------+---------------------------+
# | Recapture Creek                      | PMF       |                     39.72 |
# +--------------------------------------+-----------+---------------------------+
# | NORTH UTAH COUNTY - SILVER LAKE FLAT | PMF       |                     38.77 |
# +--------------------------------------+-----------+---------------------------+
# | BROWNS DRAW                          | Estimated |                     38.3  |
# +--------------------------------------+-----------+---------------------------+
# | GUNNISON BEND                        | PMF       |                     38.27 |
# +--------------------------------------+-----------+---------------------------+
# | PARADISE PARK                        | Estimated |                     37.76 |
# +--------------------------------------+-----------+---------------------------+
# | GUNNISON                             | PMF       |                     37.37 |
# +--------------------------------------+-----------+---------------------------+
# | BROWNS DRAW                          | PMF       |                     37.01 |
# +--------------------------------------+-----------+---------------------------+
# | MILLSITE                             | Estimated |                     35.74 |
# +--------------------------------------+-----------+---------------------------+
# | MONA                                 | PMF       |                     34.23 |
# +--------------------------------------+-----------+---------------------------+
# | UTAH POWER & LIGHT - ELECTRIC LAKE   | PMF       |                     32.36 |
# +--------------------------------------+-----------+---------------------------+
# | Recapture Creek                      | Sunny     |                     31.01 |
# +--------------------------------------+-----------+---------------------------+
# | ROCKY FORD (SEVIER)                  | PMF       |                     30.6  |
# +--------------------------------------+-----------+---------------------------+
# | COTTONWOOD                           | PMF       |                     29.53 |
# +--------------------------------------+-----------+---------------------------+
# | TROPIC                               | PMF       |                     28.45 |
# +--------------------------------------+-----------+---------------------------+
# | COTTONWOOD                           | Sunny     |                     27.44 |
# +--------------------------------------+-----------+---------------------------+
# | MONA                                 | Sunny     |                     26.35 |
# +--------------------------------------+-----------+---------------------------+
# | TWIN POTS                            | PMF       |                     25.79 |
# +--------------------------------------+-----------+---------------------------+
# | FOOL CREEK NO. 1                     | Sunny     |                     24.61 |
# +--------------------------------------+-----------+---------------------------+
# | NORTH UTAH COUNTY - SILVER LAKE FLAT | Sunny     |                     22.02 |
# +--------------------------------------+-----------+---------------------------+
# | ASH CREEK                            | PMF       |                     21.21 |
# +--------------------------------------+-----------+---------------------------+
# | QUAIL CREEK                          | PMF       |                     20.86 |
# +--------------------------------------+-----------+---------------------------+
# | QUAIL CREEK SOUTH DAM                | PMF       |                     20.75 |
# +--------------------------------------+-----------+---------------------------+
# | WHITNEY                              | PMF       |                     20.5  |
# +--------------------------------------+-----------+---------------------------+
# | CHEPETA                              | PMF       |                     20.23 |
# +--------------------------------------+-----------+---------------------------+
# | MANDERFIELD (AKA BEAVER)             | PMF       |                     20.14 |
# +--------------------------------------+-----------+---------------------------+
# | KOLOB CREEK                          | PMF       |                     19.8  |
# +--------------------------------------+-----------+---------------------------+
# | MOUNTAIN DELL                        | PMF       |                     19.05 |
# +--------------------------------------+-----------+---------------------------+
# | MILL MEADOW                          | PMF       |                     18.06 |
# +--------------------------------------+-----------+---------------------------+
# | OTTER CREEK                          | Estimated |                     17.8  |
# +--------------------------------------+-----------+---------------------------+
#
# Enter a dam name to analyze or type 'ALL' for every dam

# %%
selected = input("Dam name: ").strip()
if not selected:
    selected = dams[0][0]  # largest dam by area

if selected.upper() == "ALL":
    dam_names = [d[0] for d in dams]
else:
    dam_names = [selected]
# Out:
# Dam name:  ALL

# %%
for dam in dam_names:
    print("\n" + "=" * 60)
    print(f"POWER-PLANT RISK REPORT FOR {dam}")
    print("=" * 60)
    plants = analyze_power_plants_at_risk(conn, dam)
    print(f"\nTotal plants at risk: {len(plants)}\n")
# Out:
# ============================================================
# POWER-PLANT RISK REPORT FOR SEVIER BRIDGE
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'SEVIER BRIDGE'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR SEVIER BRIDGE
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'SEVIER BRIDGE'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR DMAD
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'DMAD'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR PIUTE
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'PIUTE'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR SETTLEMENT CANYON
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'SETTLEMENT CANYON'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR NEWCASTLE
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'NEWCASTLE'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR ENTERPRISE (UPPER)
# ============================================================
#
# --- Power Plants at Risk ---
# +-------------------+--------------------+----------------+-----------------+
# | Plant Name        | Type               | Primary Fuel   |   Capacity (MW) |
# +===================+====================+================+=================+
# | BERYL SOLAR PLANT | SOLAR PHOTOVOLTAIC | SUN            |               3 |
# +-------------------+--------------------+----------------+-----------------+
#
# Total plants at risk: 1
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR ENTERPRISE (LOWER)
# ============================================================
#
# --- Power Plants at Risk ---
# +-------------------+--------------------+----------------+-----------------+
# | Plant Name        | Type               | Primary Fuel   |   Capacity (MW) |
# +===================+====================+================+=================+
# | BERYL SOLAR PLANT | SOLAR PHOTOVOLTAIC | SUN            |               3 |
# +-------------------+--------------------+----------------+-----------------+
#
# Total plants at risk: 1
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR Big Sand Wash
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'Big Sand Wash'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR NEWCASTLE
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'NEWCASTLE'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR CLIFF LAKE (DUCHESNE)
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'CLIFF LAKE (DUCHESNE)'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR SETTLEMENT CANYON
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'SETTLEMENT CANYON'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR WHITEROCKS LAKE
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'WHITEROCKS LAKE'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR CLIFF LAKE (DUCHESNE)
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'CLIFF LAKE (DUCHESNE)'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR DMAD
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'DMAD'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR WHITEROCKS LAKE
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'WHITEROCKS LAKE'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR ROCKY FORD (BEAVER)
# ============================================================
#
# --- Power Plants at Risk ---
# +--------------------------+--------------------+----------------+-----------------+
# | Plant Name               | Type               | Primary Fuel   |   Capacity (MW) |
# +==========================+====================+================+=================+
# | MILFORD FLAT SOLAR PLANT | SOLAR PHOTOVOLTAIC | SUN            |               3 |
# +--------------------------+--------------------+----------------+-----------------+
# | MILFORD FLAT SOLAR PLANT | SOLAR PHOTOVOLTAIC | SUN            |               3 |
# +--------------------------+--------------------+----------------+-----------------+
# | GRANITE PEAK SOLAR PLANT | SOLAR PHOTOVOLTAIC | SUN            |               3 |
# +--------------------------+--------------------+----------------+-----------------+
# | GRANITE PEAK SOLAR PLANT | SOLAR PHOTOVOLTAIC | SUN            |               3 |
# +--------------------------+--------------------+----------------+-----------------+
#
# Total plants at risk: 4
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR PORCUPINE
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'PORCUPINE'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR UTAH POWER & LIGHT - CUTLER
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'UTAH POWER & LIGHT - CUTLER'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR ROCKY FORD (BEAVER)
# ============================================================
#
# --- Power Plants at Risk ---
# +--------------------------+--------------------+----------------+-----------------+
# | Plant Name               | Type               | Primary Fuel   |   Capacity (MW) |
# +==========================+====================+================+=================+
# | MILFORD FLAT SOLAR PLANT | SOLAR PHOTOVOLTAIC | SUN            |               3 |
# +--------------------------+--------------------+----------------+-----------------+
# | MILFORD FLAT SOLAR PLANT | SOLAR PHOTOVOLTAIC | SUN            |               3 |
# +--------------------------+--------------------+----------------+-----------------+
# | GRANITE PEAK SOLAR PLANT | SOLAR PHOTOVOLTAIC | SUN            |               3 |
# +--------------------------+--------------------+----------------+-----------------+
# | GRANITE PEAK SOLAR PLANT | SOLAR PHOTOVOLTAIC | SUN            |               3 |
# +--------------------------+--------------------+----------------+-----------------+
#
# Total plants at risk: 4
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR CHEPETA
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'CHEPETA'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR Recapture Creek
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'Recapture Creek'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR NORTH UTAH COUNTY - SILVER LAKE FLAT
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'NORTH UTAH COUNTY - SILVER LAKE FLAT'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR BROWNS DRAW
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'BROWNS DRAW'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR GUNNISON BEND
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'GUNNISON BEND'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR PARADISE PARK
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'PARADISE PARK'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR GUNNISON
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'GUNNISON'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR BROWNS DRAW
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'BROWNS DRAW'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR MILLSITE
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'MILLSITE'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR MONA
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'MONA'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR UTAH POWER & LIGHT - ELECTRIC LAKE
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'UTAH POWER & LIGHT - ELECTRIC LAKE'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR Recapture Creek
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'Recapture Creek'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR ROCKY FORD (SEVIER)
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'ROCKY FORD (SEVIER)'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR COTTONWOOD
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'COTTONWOOD'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR TROPIC
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'TROPIC'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR COTTONWOOD
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'COTTONWOOD'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR MONA
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'MONA'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR TWIN POTS
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'TWIN POTS'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR FOOL CREEK NO. 1
#
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'FOOL CREEK NO. 1
# '.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR NORTH UTAH COUNTY - SILVER LAKE FLAT
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'NORTH UTAH COUNTY - SILVER LAKE FLAT'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR ASH CREEK
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'ASH CREEK'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR QUAIL CREEK
# ============================================================
#
# --- Power Plants at Risk ---
# +----------------------------+--------------------------------------+----------------+-----------------+
# | Plant Name                 | Type                                 | Primary Fuel   |   Capacity (MW) |
# +============================+======================================+================+=================+
# | MILLCREEK POWER GENERATION | NATURAL GAS FIRED COMBUSTION TURBINE | NG             |            73.6 |
# +----------------------------+--------------------------------------+----------------+-----------------+
#
# Total plants at risk: 1
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR QUAIL CREEK SOUTH DAM
# ============================================================
#
# --- Power Plants at Risk ---
# +----------------------------+--------------------------------------+----------------+-----------------+
# | Plant Name                 | Type                                 | Primary Fuel   |   Capacity (MW) |
# +============================+======================================+================+=================+
# | MILLCREEK POWER GENERATION | NATURAL GAS FIRED COMBUSTION TURBINE | NG             |            73.6 |
# +----------------------------+--------------------------------------+----------------+-----------------+
#
# Total plants at risk: 1
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR WHITNEY
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'WHITNEY'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR CHEPETA
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'CHEPETA'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR MANDERFIELD (AKA BEAVER)
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'MANDERFIELD (AKA BEAVER)'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR KOLOB CREEK
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'KOLOB CREEK'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR MOUNTAIN DELL
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'MOUNTAIN DELL'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR MILL MEADOW
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'MILL MEADOW'.
#
# Total plants at risk: 0
#
#
# ============================================================
# POWER-PLANT RISK REPORT FOR OTTER CREEK
# ============================================================
#
# --- Power Plants at Risk ---
# No power plants found within the inundation zone of 'OTTER CREEK'.
#
# Total plants at risk: 0

# %%
conn.close()
